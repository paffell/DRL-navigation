# %% [markdown]
# # Navigation
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the first project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893).
#
# ### 1. Start the Environment
#
# We begin by importing some necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Banana.app"`
# - **Windows** (x86): `"path/to/Banana_Windows_x86/Banana.exe"`
# - **Windows** (x86_64): `"path/to/Banana_Windows_x86_64/Banana.exe"`
# - **Linux** (x86): `"path/to/Banana_Linux/Banana.x86"`
# - **Linux** (x86_64): `"path/to/Banana_Linux/Banana.x86_64"`
# - **Linux** (x86, headless): `"path/to/Banana_Linux_NoVis/Banana.x86"`
# - **Linux** (x86_64, headless): `"path/to/Banana_Linux_NoVis/Banana.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Banana.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Banana.app")
# ```

# %%
env = UnityEnvironment(file_name="Banana_Windows_x86_64/Banana.exe")
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: BananaBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 37
#         Number of stacked Vector Observation: 1
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# The simulation contains a single agent that navigates a large environment.  At each time step, it has four actions at its disposal:
# - `0` - walk forward
# - `1` - walk backward
# - `2` - turn left
# - `3` - turn right
#
# The state space has `37` dimensions and contains the agent's velocity, along with ray-based perception of objects around agent's forward direction.  A reward of `+1` is provided for collecting a yellow banana, and a reward of `-1` is provided for collecting a blue banana.
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents in the environment
print('Number of agents:', len(env_info.agents))

# number of actions
action_size = brain.vector_action_space_size
print('Number of actions:', action_size)

# examine the state space 
state = env_info.vector_observations[0]
print('States look like:', state)
state_size = len(state)
print('States have length:', state_size)
# Out:
# Number of agents: 1
# Number of actions: 4
# States look like: [1.         0.         0.         0.         0.84408134 0.
#  0.         1.         0.         0.0748472  0.         1.
#  0.         0.         0.25755    1.         0.         0.
#  0.         0.74177343 0.         1.         0.         0.
#  0.25854847 0.         0.         1.         0.         0.09355672
#  0.         1.         0.         0.         0.31969345 0.
#  0.        ]
# States have length: 37

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action (uniformly) at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
env_info = env.reset(train_mode=False)[brain_name] # reset the environment
state = env_info.vector_observations[0]            # get the current state
score = 0                                          # initialize the score
for j in range(400):
    action = np.random.randint(action_size) 
    action = 2# select an action
    env_info = env.step(action)[brain_name]        # send the action to the environment
    next_state = env_info.vector_observations[0]   # get the next state
    reward = env_info.rewards[0]                   # get the reward
    done = env_info.local_done[0]                  # see if episode has finished
    score += reward                                # update the score
    state = next_state                             # roll over the state to next time step
    if done:                                       # exit loop if episode finished
        break
    
print("Score: {}".format(score))
# Out:
# Score: 0.0

# %% [markdown]
# When finished, you can close the environment.

# %%
env.close()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %%
from collections import deque
from dqn_agent import Agent
import matplotlib.pyplot as plt
import torch

agent = Agent(state_size=37, action_size=4, seed=0)

def dqn(n_episodes=2000, max_t=300, eps_start=1.0, eps_end=0.01, eps_decay=0.995):
    """Deep Q-Learning.
    
    Params
    ======
        n_episodes (int): maximum number of training episodes
        max_t (int): maximum number of timesteps per episode
        eps_start (float): starting value of epsilon, for epsilon-greedy action selection
        eps_end (float): minimum value of epsilon
        eps_decay (float): multiplicative factor (per episode) for decreasing epsilon
    """
    scores = []                        # list containing scores from each episode
    scores_window = deque(maxlen=100)  # last 100 scores
    eps = eps_start                    # initialize epsilon
    for i_episode in range(1, n_episodes+1):
#         state = env.reset()
        env_info = env.reset(train_mode=True)[brain_name]
        state = env_info.vector_observations[0]
        score = 0
        for t in range(max_t):
            action = agent.act(state, eps).astype(int)
            env_info = env.step(action)[brain_name]        # send the action to the environment
            next_state = env_info.vector_observations[0]   # get the next state
            reward = env_info.rewards[0]                   # get the reward
            done = env_info.local_done[0]                  # see if episode has finished
            agent.step(state, action, reward, next_state, done)
            score += reward                                # update the score
            state = next_state 
            if done:
                break 
        print("")
        print("Score: {}".format(score))
        scores_window.append(score)       # save most recent score
        scores.append(score)              # save most recent score
        eps = max(eps_end, eps_decay*eps) # decrease epsilon
        print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_window)), end="")
        if i_episode % 100 == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_window)))
            torch.save(agent.qnetwork_local.state_dict(), 'checkpoint.pth')
        if np.mean(scores_window)>=13.0:
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(i_episode-100, np.mean(scores_window)))
            torch.save(agent.qnetwork_local.state_dict(), 'checkpoint_best.pth')
            break
    return scores

scores = dqn(4000, 300)
# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Out:
# Score: 0.0
# Episode 1	Average Score: 0.00
# Score: 0.0
# Episode 2	Average Score: 0.00
# Score: 1.0
# Episode 3	Average Score: 0.33
# Score: 0.0
# Episode 4	Average Score: 0.25
# Score: 0.0
# Episode 5	Average Score: 0.20
# Score: 0.0
# Episode 6	Average Score: 0.17
# Score: 1.0
# Episode 7	Average Score: 0.29
# Score: 1.0
# Episode 8	Average Score: 0.38
# Score: -2.0
# Episode 9	Average Score: 0.11
# Score: 0.0
# Episode 10	Average Score: 0.10
# Score: 0.0
# Episode 11	Average Score: 0.09
# Score: 0.0
# Episode 12	Average Score: 0.08
# Score: 0.0
# Episode 13	Average Score: 0.08
# Score: 0.0
# Episode 14	Average Score: 0.07
# Score: -1.0
# Episode 15	Average Score: 0.00
# Score: 1.0
# Episode 16	Average Score: 0.06
# Score: 0.0
# Episode 17	Average Score: 0.06
# Score: 0.0
# Episode 18	Average Score: 0.06
# Score: 1.0
# Episode 19	Average Score: 0.11
# Score: -1.0
# Episode 20	Average Score: 0.05
# Score: 0.0
# Episode 21	Average Score: 0.05
# Score: 2.0
# Episode 22	Average Score: 0.14
# Score: 0.0
# Episode 23	Average Score: 0.13
# Score: 0.0
# Episode 24	Average Score: 0.12
# Score: 0.0
# Episode 25	Average Score: 0.12
# Score: 1.0
# Episode 26	Average Score: 0.15
# Score: 1.0
# Episode 27	Average Score: 0.19
# Score: 1.0
# Episode 28	Average Score: 0.21
# Score: 0.0
# Episode 29	Average Score: 0.21
# Score: 0.0
# Episode 30	Average Score: 0.20
# Score: 1.0
# Episode 31	Average Score: 0.23
# Score: -2.0
# Episode 32	Average Score: 0.16
# Score: 1.0
# Episode 33	Average Score: 0.18
# Score: 1.0
# Episode 34	Average Score: 0.21
# Score: 1.0
# Episode 35	Average Score: 0.23
# Score: 1.0
# Episode 36	Average Score: 0.25
# Score: -1.0
# Episode 37	Average Score: 0.22
# Score: -1.0
# Episode 38	Average Score: 0.18
# Score: 2.0
# Episode 39	Average Score: 0.23
# Score: 0.0
# Episode 40	Average Score: 0.23
# Score: -1.0
# Episode 41	Average Score: 0.20
# Score: 0.0
# Episode 42	Average Score: 0.19
# Score: 2.0
# Episode 43	Average Score: 0.23
# Score: 1.0
# Episode 44	Average Score: 0.25
# Score: 1.0
# Episode 45	Average Score: 0.27
# Score: 1.0
# Episode 46	Average Score: 0.28
# Score: -1.0
# Episode 47	Average Score: 0.26
# Score: 0.0
# Episode 48	Average Score: 0.25
# Score: 1.0
# Episode 49	Average Score: 0.27
# Score: 2.0
# Episode 50	Average Score: 0.30
# Score: 2.0
# Episode 51	Average Score: 0.33
# Score: -1.0
# Episode 52	Average Score: 0.31
# Score: 3.0
# Episode 53	Average Score: 0.36
# Score: 2.0
# Episode 54	Average Score: 0.39
# Score: 0.0
# Episode 55	Average Score: 0.38
# Score: 1.0
# Episode 56	Average Score: 0.39
# Score: 0.0
# Episode 57	Average Score: 0.39
# Score: 2.0
# Episode 58	Average Score: 0.41
# Score: 1.0
# Episode 59	Average Score: 0.42
# Score: 0.0
# Episode 60	Average Score: 0.42
# Score: 2.0
# Episode 61	Average Score: 0.44
# Score: 1.0
# Episode 62	Average Score: 0.45
# Score: -3.0
# Episode 63	Average Score: 0.40
# Score: 1.0
# Episode 64	Average Score: 0.41
# Score: 1.0
# Episode 65	Average Score: 0.42
# Score: -1.0
# Episode 66	Average Score: 0.39
# Score: 2.0
# Episode 67	Average Score: 0.42
# Score: 0.0
# Episode 68	Average Score: 0.41
# Score: -1.0
# Episode 69	Average Score: 0.39
# Score: 1.0
# Episode 70	Average Score: 0.40
# Score: 0.0
# Episode 71	Average Score: 0.39
# Score: 1.0
# Episode 72	Average Score: 0.40
# Score: 0.0
# Episode 73	Average Score: 0.40
# Score: 0.0
# Episode 74	Average Score: 0.39
# Score: 3.0
# Episode 75	Average Score: 0.43
# Score: 6.0
# Episode 76	Average Score: 0.50
# Score: 1.0
# Episode 77	Average Score: 0.51
# Score: 3.0
# Episode 78	Average Score: 0.54
# Score: 4.0
# Episode 79	Average Score: 0.58
# Score: 1.0
# Episode 80	Average Score: 0.59
# Score: 2.0
# Episode 81	Average Score: 0.60
# Score: 4.0
# Episode 82	Average Score: 0.65
# Score: 4.0
# Episode 83	Average Score: 0.69
# Score: 3.0
# Episode 84	Average Score: 0.71
# Score: 0.0
# Episode 85	Average Score: 0.71
# Score: 3.0
# Episode 86	Average Score: 0.73
# Score: 1.0
# Episode 87	Average Score: 0.74
# Score: 4.0
# Episode 88	Average Score: 0.77
# Score: 4.0
# Episode 89	Average Score: 0.81
# Score: 6.0
# Episode 90	Average Score: 0.87
# Score: 2.0
# Episode 91	Average Score: 0.88
# Score: -1.0
# Episode 92	Average Score: 0.86
# Score: 2.0
# Episode 93	Average Score: 0.87
# Score: 5.0
# Episode 94	Average Score: 0.91
# Score: 1.0
# Episode 95	Average Score: 0.92
# Score: -1.0
# Episode 96	Average Score: 0.90
# Score: 5.0
# Episode 97	Average Score: 0.94
# Score: 5.0
# Episode 98	Average Score: 0.98
# Score: 0.0
# Episode 99	Average Score: 0.97
# Score: 2.0
# Episode 100	Average Score: 0.98
#
# Score: 2.0
# Episode 101	Average Score: 1.00
# Score: 7.0
# Episode 102	Average Score: 1.07
# Score: 5.0
# Episode 103	Average Score: 1.11
# Score: 5.0
# Episode 104	Average Score: 1.16
# Score: 7.0
# Episode 105	Average Score: 1.23
# Score: 1.0
# Episode 106	Average Score: 1.24
# Score: 0.0
# Episode 107	Average Score: 1.23
# Score: 5.0
# Episode 108	Average Score: 1.27
# Score: 4.0
# Episode 109	Average Score: 1.33
# Score: 0.0
# Episode 110	Average Score: 1.33
# Score: 5.0
# Episode 111	Average Score: 1.38
# Score: 4.0
# Episode 112	Average Score: 1.42
# Score: 6.0
# Episode 113	Average Score: 1.48
# Score: 5.0
# Episode 114	Average Score: 1.53
# Score: 6.0
# Episode 115	Average Score: 1.60
# Score: 4.0
# Episode 116	Average Score: 1.63
# Score: 6.0
# Episode 117	Average Score: 1.69
# Score: 4.0
# Episode 118	Average Score: 1.73
# Score: 4.0
# Episode 119	Average Score: 1.76
# Score: 9.0
# Episode 120	Average Score: 1.86
# Score: 4.0
# Episode 121	Average Score: 1.90
# Score: 2.0
# Episode 122	Average Score: 1.90
# Score: 4.0
# Episode 123	Average Score: 1.94
# Score: 5.0
# Episode 124	Average Score: 1.99
# Score: 8.0
# Episode 125	Average Score: 2.07
# Score: 3.0
# Episode 126	Average Score: 2.09
# Score: 3.0
# Episode 127	Average Score: 2.11
# Score: 2.0
# Episode 128	Average Score: 2.12
# Score: 4.0
# Episode 129	Average Score: 2.16
# Score: 3.0
# Episode 130	Average Score: 2.19
# Score: 8.0
# Episode 131	Average Score: 2.26
# Score: 6.0
# Episode 132	Average Score: 2.34
# Score: 4.0
# Episode 133	Average Score: 2.37
# Score: 2.0
# Episode 134	Average Score: 2.38
# Score: 0.0
# Episode 135	Average Score: 2.37
# Score: 2.0
# Episode 136	Average Score: 2.38
# Score: 5.0
# Episode 137	Average Score: 2.44
# Score: 8.0
# Episode 138	Average Score: 2.53
# Score: 5.0
# Episode 139	Average Score: 2.56
# Score: 5.0
# Episode 140	Average Score: 2.61
# Score: 4.0
# Episode 141	Average Score: 2.66
# Score: 2.0
# Episode 142	Average Score: 2.68
# Score: 8.0
# Episode 143	Average Score: 2.74
# Score: 6.0
# Episode 144	Average Score: 2.79
# Score: 4.0
# Episode 145	Average Score: 2.82
# Score: 6.0
# Episode 146	Average Score: 2.87
# Score: 3.0
# Episode 147	Average Score: 2.91
# Score: 11.0
# Episode 148	Average Score: 3.02
# Score: 8.0
# Episode 149	Average Score: 3.09
# Score: 0.0
# Episode 150	Average Score: 3.07
# Score: 7.0
# Episode 151	Average Score: 3.12
# Score: 6.0
# Episode 152	Average Score: 3.19
# Score: 8.0
# Episode 153	Average Score: 3.24
# Score: 5.0
# Episode 154	Average Score: 3.27
# Score: 7.0
# Episode 155	Average Score: 3.34
# Score: 4.0
# Episode 156	Average Score: 3.37
# Score: 4.0
# Episode 157	Average Score: 3.41
# Score: 7.0
# Episode 158	Average Score: 3.46
# Score: 1.0
# Episode 159	Average Score: 3.46
# Score: 6.0
# Episode 160	Average Score: 3.52
# Score: 7.0
# Episode 161	Average Score: 3.57
# Score: 5.0
# Episode 162	Average Score: 3.61
# Score: 10.0
# Episode 163	Average Score: 3.74
# Score: 4.0
# Episode 164	Average Score: 3.77
# Score: 6.0
# Episode 165	Average Score: 3.82
# Score: 5.0
# Episode 166	Average Score: 3.88
# Score: 7.0
# Episode 167	Average Score: 3.93
# Score: 9.0
# Episode 168	Average Score: 4.02
# Score: 9.0
# Episode 169	Average Score: 4.12
# Score: 8.0
# Episode 170	Average Score: 4.19
# Score: 6.0
# Episode 171	Average Score: 4.25
# Score: 4.0
# Episode 172	Average Score: 4.28
# Score: 5.0
# Episode 173	Average Score: 4.33
# Score: 3.0
# Episode 174	Average Score: 4.36
# Score: 3.0
# Episode 175	Average Score: 4.36
# Score: 7.0
# Episode 176	Average Score: 4.37
# Score: 6.0
# Episode 177	Average Score: 4.42
# Score: 7.0
# Episode 178	Average Score: 4.46
# Score: 6.0
# Episode 179	Average Score: 4.48
# Score: 8.0
# Episode 180	Average Score: 4.55
# Score: 1.0
# Episode 181	Average Score: 4.54
# Score: 5.0
# Episode 182	Average Score: 4.55
# Score: 3.0
# Episode 183	Average Score: 4.54
# Score: 2.0
# Episode 184	Average Score: 4.53
# Score: 9.0
# Episode 185	Average Score: 4.62
# Score: 9.0
# Episode 186	Average Score: 4.68
# Score: 0.0
# Episode 187	Average Score: 4.67
# Score: 5.0
# Episode 188	Average Score: 4.68
# Score: 3.0
# Episode 189	Average Score: 4.67
# Score: 10.0
# Episode 190	Average Score: 4.71
# Score: 8.0
# Episode 191	Average Score: 4.77
# Score: 9.0
# Episode 192	Average Score: 4.87
# Score: 6.0
# Episode 193	Average Score: 4.91
# Score: 5.0
# Episode 194	Average Score: 4.91
# Score: 6.0
# Episode 195	Average Score: 4.96
# Score: 10.0
# Episode 196	Average Score: 5.07
# Environment solved in 96 episodes!	Average Score: 5.07

# %% [markdown]
# Watch it

# %%
env_info = env.reset(train_mode=False)[brain_name] # reset the environment
state = env_info.vector_observations[0]            # get the current state
score = 0                                          # initialize the score


for j in range(200):
    action = agent.act(state).astype(int)
    env_info = env.step(action)[brain_name]        # send the action to the environment
    next_state = env_info.vector_observations[0]   # get the next state
    reward = env_info.rewards[0]                   # get the reward
    done = env_info.local_done[0]                  # see if episode has finished
    score += reward                                # update the score
    state = next_state                             # roll over the state to next time step
    if done:                                       # exit loop if episode finished
        break
    
print("Score: {}".format(score))
# Out:
# Score: 0.0
